# %%
# !pip install pandas

# %%
import pandas as pd

# %%
df= pd.read_csv ('https://raw.githubusercontent.com/thousandoaks/BEMM458/master/data/gapminder.tsv', sep='\t')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.iloc[[10,100,1000]]
# Out:
#           country continent  year  lifeExp       pop    gdpPercap
# 10    Afghanistan      Asia  2002   42.129  25268405   726.734055
# 100    Bangladesh      Asia  1972   45.252  70759295   630.233627
# 1000     Mongolia      Asia  1972   53.754   1320500  1421.741975

# %% [markdown]
# How to select certain rows and coloumns

# %%
df_new=df[['country','year','pop']]

# %%
df_new.iloc[[10,100,1000]]
# Out:
#           country  year       pop
# 10    Afghanistan  2002  25268405
# 100    Bangladesh  1972  70759295
# 1000     Mongolia  1972   1320500

# %% [markdown]
# Or we can do it in one row but this wont save the data set as a new data set

# %%
df[['country','year','pop']].iloc[[10,100,1000]]
# Out:
#           country  year       pop
# 10    Afghanistan  2002  25268405
# 100    Bangladesh  1972  70759295
# 1000     Mongolia  1972   1320500
